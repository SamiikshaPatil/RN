# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn import metrics

# %%
# Load the ocr dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print("X_train shape", x_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", x_test.shape)
print("y_test shape", y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# X_train shape (60000, 28, 28)
# y_train shape (60000,)
# X_test shape (10000, 28, 28)
# y_test shape (10000,)

# %%
# Reshape the dataset as it is 3 dimensional
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32') #from int to float
x_test = x_test.astype('float32')
x_train /= 255 # Each image has Intensity from 0 to 255
x_test /= 255
num_classes = 10
y_train = np.eye(num_classes)[y_train]
y_test = np.eye(num_classes)[y_test]

# %%
# Build the model
import tensorflow as tf
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy',optimizer=RMSprop(),metrics=['accuracy'])

# %%
# Train the model
batch_size = 128
epochs = 20
history = model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test,y_test))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 15s 29ms/step - loss: 0.2565 - accuracy: 0.9218 - val_loss: 0.1126 - val_accuracy: 0.9649
# Epoch 2/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.1034 - accuracy: 0.9683 - val_loss: 0.0792 - val_accuracy: 0.9755
# Epoch 3/20
# 469/469 [==============================] - 11s 22ms/step - loss: 0.0733 - accuracy: 0.9767 - val_loss: 0.0744 - val_accuracy: 0.9782
# Epoch 4/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0587 - accuracy: 0.9819 - val_loss: 0.0702 - val_accuracy: 0.9790
# Epoch 5/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0490 - accuracy: 0.9842 - val_loss: 0.0686 - val_accuracy: 0.9818
# Epoch 6/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0404 - accuracy: 0.9872 - val_loss: 0.0639 - val_accuracy: 0.9827
# Epoch 7/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0327 - accuracy: 0.9900 - val_loss: 0.0599 - val_accuracy: 0.9836
# Epoch 8/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0295 - accuracy: 0.9907 - val_loss: 0.0677 - val_accuracy: 0.9819
# Epoch 9/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0247 - accuracy: 0.9921 - val_loss: 0.0706 - val_accuracy: 0.9830
# Epoch 10/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.0621 - val_accuracy: 0.9845
# Epoch 11/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0216 - accuracy: 0.9934 - val_loss: 0.0830 - val_accuracy: 0.9817
# Epoch 12/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0720 - val_accuracy: 0.9837
# Epoch 13/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0164 - accuracy: 0.9948 - val_loss: 0.0750 - val_accuracy: 0.9830
# Epoch 14/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.0713 - val_accuracy: 0.9840
# Epoch 15/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.0835 - val_accuracy: 0.9820
# Epoch 16/20
# 469/469 [==============================] - 11s 22ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0786 - val_accuracy: 0.9834
# Epoch 17/20
# 469/469 [==============================] - 11s 22ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.0789 - val_accuracy: 0.9848
# Epoch 18/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0842 - val_accuracy: 0.9849
# Epoch 19/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.0962 - val_accuracy: 0.9828
# Epoch 20/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0891 - val_accuracy: 0.9832

# %%
# Evaluate the model
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.0890534371137619
# Test accuracy: 0.9832000136375427
